# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /srv/conda/envs/notebook/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /srv/conda/envs/notebook/lib/python3.11/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load prepared weather dataset

# %%
weather_data_url = "https://drive.google.com/file/d/1chmMsKkMnzE1Xi347Za9ZWyMtuOpTe3T/view?usp=sharing"
weather_data_download_url = 'https://drive.google.com/uc?id=' + weather_data_url.split('/')[-2]

weather_data_download_url
# Out:
# 'https://drive.google.com/uc?id=1chmMsKkMnzE1Xi347Za9ZWyMtuOpTe3T'

# %%
weather = pd.read_csv(weather_data_download_url)

# %%
weather
# Out:
#        SCODE eastBoundingCoordinate northBoundingCoordinate  altitudeMinimum  \
# 0        NaN                 14,442                  47,842              893
# 1        NaN                 14,442                  47,842              893
# 2        NaN                 14,442                  47,842              893
# 3        NaN                 14,442                  47,842              893
# 4        NaN                 14,442                  47,842              893
# ...      ...                    ...                     ...              ...
# 74193    NaN                 14,442                  47,842              893
# 74194    NaN                 14,442                  47,842              893
# 74195    NaN                 14,442                  47,842              893
# 74196    NaN                 14,442                  47,842              893
# 74197    NaN                 14,442                  47,842              893
#
#        YEAR  MONTH  MONTH_NORMALIZED  DAY  DAY_NORMALIZED      Date  TAXA  \
# 0      1995     10                10    4               4  19951004   NaN
# 1      1995     10                10    5               5  19951005   NaN
# 2      1995     10                10    6               6  19951006   NaN
# 3      1995     10                10    7               7  19951007   NaN
# 4      1995     10                10    8               8  19951008   NaN
# ...     ...    ...               ...  ...             ...       ...   ...
# 74193  2016     12                12   28              28  20161228   NaN
# 74194  2016     12                12   29              29  20161229   NaN
# 74195  2016     12                12   30              30  20161230   NaN
# 74196  2016     12                12   31              31  20161231   NaN
# 74197  2017      1                 1    1               1  20170101   NaN
#
#          SUBST                     Ref_SUBST   METHOD_CODE       LAB_METHOD  \
# 0          tas  Near-Surface Air Temperature      METH.tas     Kroneis NTC
# 1          tas  Near-Surface Air Temperature      METH.tas     Kroneis NTC
# 2          tas  Near-Surface Air Temperature      METH.tas     Kroneis NTC
# 3          tas  Near-Surface Air Temperature      METH.tas     Kroneis NTC
# 4          tas  Near-Surface Air Temperature      METH.tas     Kroneis NTC
# ...        ...                           ...           ...              ...
# 74193  WindDir                Wind direction  METH.WindDir  Kroneis, 263PRH
# 74194  WindDir                Wind direction  METH.WindDir  Kroneis, 263PRH
# 74195  WindDir                Wind direction  METH.WindDir  Kroneis, 263PRH
# 74196  WindDir                Wind direction  METH.WindDir  Kroneis, 263PRH
# 74197  WindDir                Wind direction  METH.WindDir  Kroneis, 263PRH
#
#         VALUE     UNIT LISTSUB
# 0       13,59       °C  CORDEX
# 1       14,11       °C  CORDEX
# 2       13,56       °C  CORDEX
# 3       13,27       °C  CORDEX
# 4       13,68       °C  CORDEX
# ...       ...      ...     ...
# 74193  327,62  DEGREES     OWN
# 74194  290,99  DEGREES     OWN
# 74195  308,96  DEGREES     OWN
# 74196  251,14  DEGREES     OWN
# 74197  272,23  DEGREES     OWN
#
# [74198 rows x 18 columns]

# %%
weather['time'] = pd.to_datetime(weather['Date'].astype(str), format='%Y%m%d')

# %%
weather
# Out:
#        SCODE eastBoundingCoordinate northBoundingCoordinate  altitudeMinimum  \
# 0        NaN                 14,442                  47,842              893
# 1        NaN                 14,442                  47,842              893
# 2        NaN                 14,442                  47,842              893
# 3        NaN                 14,442                  47,842              893
# 4        NaN                 14,442                  47,842              893
# ...      ...                    ...                     ...              ...
# 74193    NaN                 14,442                  47,842              893
# 74194    NaN                 14,442                  47,842              893
# 74195    NaN                 14,442                  47,842              893
# 74196    NaN                 14,442                  47,842              893
# 74197    NaN                 14,442                  47,842              893
#
#        YEAR  MONTH  MONTH_NORMALIZED  DAY  DAY_NORMALIZED      Date  TAXA  \
# 0      1995     10                10    4               4  19951004   NaN
# 1      1995     10                10    5               5  19951005   NaN
# 2      1995     10                10    6               6  19951006   NaN
# 3      1995     10                10    7               7  19951007   NaN
# 4      1995     10                10    8               8  19951008   NaN
# ...     ...    ...               ...  ...             ...       ...   ...
# 74193  2016     12                12   28              28  20161228   NaN
# 74194  2016     12                12   29              29  20161229   NaN
# 74195  2016     12                12   30              30  20161230   NaN
# 74196  2016     12                12   31              31  20161231   NaN
# 74197  2017      1                 1    1               1  20170101   NaN
#
#          SUBST                     Ref_SUBST   METHOD_CODE       LAB_METHOD  \
# 0          tas  Near-Surface Air Temperature      METH.tas     Kroneis NTC
# 1          tas  Near-Surface Air Temperature      METH.tas     Kroneis NTC
# 2          tas  Near-Surface Air Temperature      METH.tas     Kroneis NTC
# 3          tas  Near-Surface Air Temperature      METH.tas     Kroneis NTC
# 4          tas  Near-Surface Air Temperature      METH.tas     Kroneis NTC
# ...        ...                           ...           ...              ...
# 74193  WindDir                Wind direction  METH.WindDir  Kroneis, 263PRH
# 74194  WindDir                Wind direction  METH.WindDir  Kroneis, 263PRH
# 74195  WindDir                Wind direction  METH.WindDir  Kroneis, 263PRH
# 74196  WindDir                Wind direction  METH.WindDir  Kroneis, 263PRH
# 74197  WindDir                Wind direction  METH.WindDir  Kroneis, 263PRH
#
#         VALUE     UNIT LISTSUB       time
# 0       13,59       °C  CORDEX 1995-10-04
# 1       14,11       °C  CORDEX 1995-10-05
# 2       13,56       °C  CORDEX 1995-10-06
# 3       13,27       °C  CORDEX 1995-10-07
# 4       13,68       °C  CORDEX 1995-10-08
# ...       ...      ...     ...        ...
# 74193  327,62  DEGREES     OWN 2016-12-28
# 74194  290,99  DEGREES     OWN 2016-12-29
# 74195  308,96  DEGREES     OWN 2016-12-30
# 74196  251,14  DEGREES     OWN 2016-12-31
# 74197  272,23  DEGREES     OWN 2017-01-01
#
# [74198 rows x 19 columns]

# %%
# Define a custom function to combine columns
def compute_lat_mean(row):
    return float(str(row['eastBoundingCoordinate']).replace(",","."))
def compute_lon_mean(row):
    return float(str(row['northBoundingCoordinate']).replace(",","."))

def compute_value_mean(row):
    return float(str(row['VALUE']).replace(",","."))

# %%
# Apply the custom function to create a new column 'latitude_mean'
weather['eastBoundingCoordinate'] = weather.apply(compute_lat_mean, axis=1)

# %%
weather['northBoundingCoordinate'] = weather.apply(compute_lon_mean, axis=1)

# %%
weather['VALUE'] = weather.apply(compute_value_mean, axis=1)

# %% [markdown]
# ## MGRS 100m grid

# %%
import mgrs

# %%
# Define a custom function to combine columns
# Precision	Size of grid side
# 5	1m
# 4	10m
# 3	100m
# 2	1000m (1km)
# 1	10000m (10km)
# 0	100000m (100km)
def to_mgrs_compute(row):
    return mgrs.MGRS().toMGRS(row['northBoundingCoordinate'], row['eastBoundingCoordinate'],4)
# Define a custom function to combine columns
def from_mgrs_compute_lat(row):
    return mgrs.MGRS().toLatLon(row['MGRS'])[0]
# Define a custom function to combine columns
def from_mgrs_compute_lon(row):
    return mgrs.MGRS().toLatLon(row['MGRS'])[1]

# %%
# Apply the custom function to create a new column 'MGRS'
weather['MGRS'] = weather.apply(to_mgrs_compute, axis=1)

# %%
weather['lon'] = weather.apply(from_mgrs_compute_lon, axis=1)
weather['lat'] = weather.apply(from_mgrs_compute_lat, axis=1)

# %%
weather
# Out:
#        SCODE  eastBoundingCoordinate  northBoundingCoordinate  \
# 0        NaN                  14.442                   47.842
# 1        NaN                  14.442                   47.842
# 2        NaN                  14.442                   47.842
# 3        NaN                  14.442                   47.842
# 4        NaN                  14.442                   47.842
# ...      ...                     ...                      ...
# 74193    NaN                  14.442                   47.842
# 74194    NaN                  14.442                   47.842
# 74195    NaN                  14.442                   47.842
# 74196    NaN                  14.442                   47.842
# 74197    NaN                  14.442                   47.842
#
#        altitudeMinimum  YEAR  MONTH  MONTH_NORMALIZED  DAY  DAY_NORMALIZED  \
# 0                  893  1995     10                10    4               4
# 1                  893  1995     10                10    5               5
# 2                  893  1995     10                10    6               6
# 3                  893  1995     10                10    7               7
# 4                  893  1995     10                10    8               8
# ...                ...   ...    ...               ...  ...             ...
# 74193              893  2016     12                12   28              28
# 74194              893  2016     12                12   29              29
# 74195              893  2016     12                12   30              30
# 74196              893  2016     12                12   31              31
# 74197              893  2017      1                 1    1               1
#
#            Date  ...                     Ref_SUBST   METHOD_CODE  \
# 0      19951004  ...  Near-Surface Air Temperature      METH.tas
# 1      19951005  ...  Near-Surface Air Temperature      METH.tas
# 2      19951006  ...  Near-Surface Air Temperature      METH.tas
# 3      19951007  ...  Near-Surface Air Temperature      METH.tas
# 4      19951008  ...  Near-Surface Air Temperature      METH.tas
# ...         ...  ...                           ...           ...
# 74193  20161228  ...                Wind direction  METH.WindDir
# 74194  20161229  ...                Wind direction  METH.WindDir
# 74195  20161230  ...                Wind direction  METH.WindDir
# 74196  20161231  ...                Wind direction  METH.WindDir
# 74197  20170101  ...                Wind direction  METH.WindDir
#
#             LAB_METHOD   VALUE     UNIT  LISTSUB       time             MGRS  \
# 0         Kroneis NTC    13.59       °C   CORDEX 1995-10-04  33TVN5824898890
# 1         Kroneis NTC    14.11       °C   CORDEX 1995-10-05  33TVN5824898890
# 2         Kroneis NTC    13.56       °C   CORDEX 1995-10-06  33TVN5824898890
# 3         Kroneis NTC    13.27       °C   CORDEX 1995-10-07  33TVN5824898890
# 4         Kroneis NTC    13.68       °C   CORDEX 1995-10-08  33TVN5824898890
# ...                ...     ...      ...      ...        ...              ...
# 74193  Kroneis, 263PRH  327.62  DEGREES      OWN 2016-12-28  33TVN5824898890
# 74194  Kroneis, 263PRH  290.99  DEGREES      OWN 2016-12-29  33TVN5824898890
# 74195  Kroneis, 263PRH  308.96  DEGREES      OWN 2016-12-30  33TVN5824898890
# 74196  Kroneis, 263PRH  251.14  DEGREES      OWN 2016-12-31  33TVN5824898890
# 74197  Kroneis, 263PRH  272.23  DEGREES      OWN 2017-01-01  33TVN5824898890
#
#              lon        lat
# 0      14.441989  47.841999
# 1      14.441989  47.841999
# 2      14.441989  47.841999
# 3      14.441989  47.841999
# 4      14.441989  47.841999
# ...          ...        ...
# 74193  14.441989  47.841999
# 74194  14.441989  47.841999
# 74195  14.441989  47.841999
# 74196  14.441989  47.841999
# 74197  14.441989  47.841999
#
# [74198 rows x 22 columns]

# %% [markdown]
# ## Convert to Xarray to get datacube

# %%
weather["Ref_SUBST"].unique()
# Out:
# array(['Near-Surface Air Temperature',
#        'Daily Maximum Near-Surface Air Temperature',
#        'Daily Minimum Near-Surface Air Temperature', 'Precipitation',
#        'Near-Surface Relative Humidity', 'Global radiation',
#        'Duration of Sunshine', 'Surface Air Pressure',
#        'Near-Surface Wind Speed', 'Wind direction'], dtype=object)

# %%
lst_array = []
for var in weather["Ref_SUBST"].unique():
    lst_array.append(weather.loc[weather['Ref_SUBST'] == var].groupby(['time', 'lat', 'lon'])[['VALUE']].mean().rename(columns={"VALUE": var.replace(" ", "_")}).to_xarray())

# %%
import xarray as xr

# %%
xr.merge(lst_array).to_netcdf("weather.nc")

# %%
dset = xr.open_dataset("weather.nc")

# %%
dset
# Out:
# <xarray.Dataset>
# Dimensions:                                     (time: 7621, lat: 1, lon: 1)
# Coordinates:
#   * time                                        (time) datetime64[ns] 1995-09...
#   * lat                                         (lat) float64 47.84
#   * lon                                         (lon) float64 14.44
# Data variables:
#     Near-Surface_Air_Temperature                (time, lat, lon) float64 ...
#     Daily_Maximum_Near-Surface_Air_Temperature  (time, lat, lon) float64 ...
#     Daily_Minimum_Near-Surface_Air_Temperature  (time, lat, lon) float64 ...
#     Precipitation                               (time, lat, lon) float64 ...
#     Near-Surface_Relative_Humidity              (time, lat, lon) float64 ...
#     Global_radiation                            (time, lat, lon) float64 ...
#     Duration_of_Sunshine                        (time, lat, lon) float64 ...
#     Surface_Air_Pressure                        (time, lat, lon) float64 ...
#     Near-Surface_Wind_Speed                     (time, lat, lon) float64 ...
#     Wind_direction                              (time, lat, lon) float64 ...

# %% [markdown]
# # Adding attributes:
# - See https://docs.xarray.dev/en/latest/generated/xarray.DataArray.assign_attrs.html
